# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
import numpy as np
from scipy import signal
from scipy.signal import find_peaks
from scipy.interpolate import interp1d
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# # データの読み込み

# %% [markdown]
# ## 歩行軌跡と歩行速度

# %%
trajectory_file_path = "./data/trajectorySlowly.csv"
speed_file_path = "./data/speedSlowly.csv"

# 通信してデータを取得
df_trajectory = pd.read_csv(trajectory_file_path)
df_speed = pd.read_csv(speed_file_path)

# %% [markdown]
# ## データの描画

# %% [markdown]
# ### 歩行軌跡

# %%
plt.subplots_adjust(hspace=0.3)
fig = plt.figure(figsize=(10, 10))


x = df_trajectory['x']
y = df_trajectory['y'] 
time = df_trajectory['time']
# 補間された軌跡を描画
plt.colorbar(plt.scatter(x, y,c=time,cmap='rainbow',s=40, label=f'推定軌跡', zorder=2))

# 元の不規則間隔の軌跡の点も重ねて表示（補間効果の確認用）

plt.gca().set_aspect('equal', adjustable='box')
plt.title('歩行軌跡 (0.25秒間隔で時刻を同期)')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.grid(True)

plt.show()

# %% [markdown]
# ### 歩行速度

# %%
# グラフ描画
speed = df_speed['speed'] 
time = df_speed['time']
plt.figure(figsize=(10, 5))
plt.axvspan(15.0, 27.0,alpha=1.0,color="#ffcdd2",label='ゆっくり歩く')
plt.plot(df_speed['time'], df_speed['speed'], marker='o', linestyle='-', color='blue', label='(x,y)')
plt.xlabel('時間 (s)')
plt.ylabel('速さ (m/s)')
plt.title('歩行速度')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# # 閾値の設定（Threshold）

# %%
threshold = 0.24

# %% [markdown]
# # データのフィルタリング/抽出ロジック

# %%
# 時間軸での同期: 歩行軌跡データと歩行速度データは、同じ時間点に対応しているか

# 条件判定: 各時間点において、その時間点の歩行速度が設定された閾値以下であるかどうかを判定します。
if speed_i <= threshold:


# 軌跡の抽出: 条件を満たした時間点に対応するX座標とY座標の組を抽出します。

# %% [markdown]
# # 軌跡の表示
